# %% [markdown]
# # COMP0005 - GROUP COURSEWORK
# # Experimental Evaluation of Search Data Structures and Algorithms

# %% [markdown]
# The cell below defines **AbstractSearchInterface**, an interface to support basic insert/search operations; you will need to implement this three times, to realise your three search data structures of choice among: (1) *2-3 Tree*, (2) *AVL Tree*, (3) *LLRB BST*; (4) *B-Tree*; and (5) *Scapegoat Tree*. <br><br>**Do NOT modify the next cell** - use the dedicated cells further below for your implementation instead. <br>

# %%
# DO NOT MODIFY THIS CELL

from abc import ABC, abstractmethod  

class AbstractSearchInterface(ABC):
    '''
    Abstract class to support search/insert operations (plus underlying data structure)
    
    '''
        
    @abstractmethod
    def insertElement(self, element):     
        '''
        Insert an element in a search tree
            Parameters:
                    element: string to be inserted in the search tree (string)

            Returns:
                    "True" after successful insertion, "False" if element is already present (bool)
        '''
        
        pass 
    

    @abstractmethod
    def searchElement(self, element):
        '''
        Search for an element in a search tree
            Parameters:
                    element: string to be searched in the search tree (string)

            Returns:
                    "True" if element is found, "False" otherwise (bool)
        '''

        pass

# %% [markdown]
# Use the cell below to define any auxiliary data structure and python function you may need. Leave the implementation of the main API to the next code cells instead.

# %%
# ADD AUXILIARY DATA STRUCTURE DEFINITIONS AND HELPER CODE HERE

# --- AVL Tree helpers ---

class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None
        self.height = 1

def height(node):
    if not node:
        return 0
    return node.height

def AVLBalance(node):
    if not node:
        return 0
    return height(node.left) - height(node.right)

def AVLRotateRight(n):
    m = n.left
    l = m.right
    m.right = n
    n.left = l
    n.height = 1 + max(height(n.left), height(n.right))
    m.height = 1 + max(height(m.left), height(m.right))
    return m

def AVLRotateLeft(n):
    m = n.right
    l = m.left
    m.left = n
    n.right = l
    n.height = 1 + max(height(n.left), height(n.right))
    m.height = 1 + max(height(m.left), height(m.right))
    return m

def AVLInsertHelper(self, node, value):
    if not node:
        self.inserted = True
        return Node(value)
    if value < node.value:
        node.left = AVLInsertHelper(self, node.left, value)
    elif value > node.value:
        node.right = AVLInsertHelper(self, node.right, value)
    else:
        return node
    node.height = 1 + max(height(node.left), height(node.right))
    b = AVLBalance(node)
    if b < -1:  # right-heavy
        if AVLBalance(node.right) > 0:  # right-left case
            node.right = AVLRotateRight(node.right)
        return AVLRotateLeft(node)
    elif b > 1:  # left-heavy
        if AVLBalance(node.left) < 0:  # left-right case
            node.left = AVLRotateLeft(node.left)
        return AVLRotateRight(node)
    return node

def searchHelper(node, value):
    while node is not None:
        if value < node.value:
            node = node.left
        elif value > node.value:
            node = node.right
        else:
            return True
    return False


# --- 2-3 Tree helpers ---

class TwoThreeNode:
    __slots__ = ("keyList", "keyCount", "childList", "parentNode")

    def __init__(self, keyList=None, childList=None, parentNode=None):
        self.keyList = list(keyList) if keyList is not None else []
        self.keyCount = len(self.keyList)
        self.childList = list(childList) if childList is not None else []
        self.parentNode = parentNode
        if self.childList:
            for childNode in self.childList:
                childNode.parentNode = self

    def GetKeyCount(self):
        self.keyCount = len(self.keyList)
        return self.keyCount

    def IsLeaf(self):
        return len(self.childList) == 0

    def IsOverflow(self):
        return self.GetKeyCount() == 3

    def InsertKey(self, keyValue):
        self.keyList.append(keyValue)
        self.keyList.sort()
        self.GetKeyCount()
        return self.keyList.index(keyValue)

    def ChildIndexFor(self, keyValue):
        indexValue = 0
        while indexValue < self.GetKeyCount() and keyValue >= self.keyList[indexValue]:
            indexValue += 1
        return indexValue

    def SetChildren(self, childList):
        self.childList = list(childList)
        for childNode in self.childList:
            childNode.parentNode = self


# --- LLRB BST helpers ---

RED = True
BLACK = False

class LLRBNode:
    """A single node in the LLRB BST, carrying a key, a value, and a link colour."""

    def __init__(self, key, value):
        self.key = key
        self.value = value
        self.left = None
        self.right = None
        self.color = RED  # new nodes are always inserted as red


def _is_red(node):
    """Return True if node's incoming link is red; None links are black."""
    if node is None:
        return False
    return node.color == RED


def _rotate_left(h):
    """
    Rotate h left to eliminate a right-leaning red link.

    Before:  h -red-> x        After:  x
                      / \\             / \\
                     b   c         red h   c
                                   / \\
                                  a   b

    Operations:
      1. x (h.right) becomes the new subtree root.
      2. x's left subtree is transferred to h as its new right child.
      3. h becomes x's left child.
      4. x inherits h's original colour (subtree colour unchanged externally).
      5. h is coloured RED (link from x down to h is now red).

    Returns the new subtree root x.
    """
    x = h.right
    h.right = x.left
    x.left = h
    x.color = h.color
    h.color = RED
    return x


def _rotate_right(h):
    """
    Rotate h right to eliminate two consecutive left-leaning red links.

    Before:     h              After:  x
               / \\                   / \\
           red x   c               a   red h
           / \\                         / \\
          a   b                        b   c

    Operations:
      1. x (h.left) becomes the new subtree root.
      2. x's right subtree is transferred to h as its new left child.
      3. h becomes x's right child.
      4. x inherits h's original colour (subtree colour unchanged externally).
      5. h is coloured RED (link from x down to h is now red).

    Returns the new subtree root x.
    """
    x = h.left
    h.left = x.right
    x.right = h
    x.color = h.color
    h.color = RED
    return x


def _flip_colors(h):
    """
    Flip colours of h and both children to split a temporary 4-node.

    Operations:
      1. h is coloured RED  - propagates the carry up to h's parent.
      2. h.left  is coloured BLACK.
      3. h.right is coloured BLACK.

    Modifies nodes in place; returns nothing.
    """
    h.color = RED
    h.left.color = BLACK
    h.right.color = BLACK


def _llrb_put(h, key, value):
    """
    Recursive insert into the subtree rooted at h.

    Going DOWN:
      - h is None          -> create and return a new red LLRBNode.
      - key < h.key        -> recurse left.
      - key > h.key        -> recurse right.
      - key == h.key       -> update value in place (no structural change).

    Coming BACK UP (three fix-up checks in order):
      1. Right child red, left child not red  -> rotate_left  (no right-leaning reds).
      2. Left child red and left-left red     -> rotate_right (no two consecutive reds).
      3. Both children red                   -> flip_colors  (split 4-node).

    Returns the (possibly new) subtree root after fix-ups.
    """
    if h is None:
        return LLRBNode(key, value)
    if key < h.key:
        h.left = _llrb_put(h.left, key, value)
    elif key > h.key:
        h.right = _llrb_put(h.right, key, value)
    else:
        h.value = value  # duplicate key: update value
    if _is_red(h.right) and not _is_red(h.left):
        h = _rotate_left(h)
    if _is_red(h.left) and _is_red(h.left.left):
        h = _rotate_right(h)
    if _is_red(h.left) and _is_red(h.right):
        _flip_colors(h)
    return h


def _llrb_contains(root, key):
    """
    Iterative BST search (colour is irrelevant for lookup).

    Traversal:
      - key < node.key  -> go left.
      - key > node.key  -> go right.
      - key == node.key -> found; return True.
      - node is None    -> exhausted; return False.

    Returns True if key exists in the tree, False otherwise.
    """
    node = root
    while node is not None:
        if key < node.key:
            node = node.left
        elif key > node.key:
            node = node.right
        else:
            return True
    return False

# %% [markdown]
# Use the cell below to implement the requested API by means of **2-3 Tree** (if among your chosen data structure).

# %%
class TwoThreeTree(AbstractSearchInterface):

    def __init__(self, stringValue=None):
        self.rootNode = None
        if stringValue is not None:
            for elementValue in stringValue:
                self.insertElement(elementValue)

    def insertElement(self, elementValue):
        if self.rootNode is None:
            self.rootNode = TwoThreeNode([elementValue])
            return True

        # traverse to leaf, checking for duplicates at each internal node
        currentNode = self.rootNode
        while not currentNode.IsLeaf():
            if elementValue in currentNode.keyList:
                return False
            childIndexValue = currentNode.ChildIndexFor(elementValue)
            currentNode = currentNode.childList[childIndexValue]

        # check for duplicate at leaf
        if elementValue in currentNode.keyList:
            return False

        currentNode.InsertKey(elementValue)

        # fix 4-nodes up the tree
        while currentNode is not None and currentNode.IsOverflow():
            self.SplitNode(currentNode)
            currentNode = currentNode.parentNode

        return True

    def searchElement(self, elementValue):
        found = False

        currentNode = self.rootNode
        while currentNode is not None:
            keyIndexValue = 0
            while keyIndexValue < currentNode.keyCount:
                if elementValue == currentNode.keyList[keyIndexValue]:
                    return True
                keyIndexValue += 1

            if currentNode.IsLeaf():
                return False

            childIndexValue = currentNode.ChildIndexFor(elementValue)
            currentNode = currentNode.childList[childIndexValue]

        return found

    def SplitNode(self, overflowNode):
        keyA = overflowNode.keyList[0]
        keyB = overflowNode.keyList[1]  # promoted
        keyC = overflowNode.keyList[2]

        leftNode = TwoThreeNode([keyA])
        rightNode = TwoThreeNode([keyC])

        if overflowNode.childList:
            leftNode.SetChildren([overflowNode.childList[0], overflowNode.childList[1]])
            rightNode.SetChildren([overflowNode.childList[2], overflowNode.childList[3]])

        parentNode = overflowNode.parentNode

        if parentNode is None:
            self.rootNode = TwoThreeNode([keyB], [leftNode, rightNode], None)
            return

        overflowIndexValue = 0
        while (
            overflowIndexValue < len(parentNode.childList)
            and parentNode.childList[overflowIndexValue] is not overflowNode
        ):
            overflowIndexValue += 1

        if overflowIndexValue == len(parentNode.childList):
            raise ValueError("Parent does not reference overflow child.")

        parentNode.InsertKey(keyB)

        parentNode.childList.pop(overflowIndexValue)
        parentNode.childList.insert(overflowIndexValue, leftNode)
        parentNode.childList.insert(overflowIndexValue + 1, rightNode)
        leftNode.parentNode = parentNode
        rightNode.parentNode = parentNode

        self.NormalizeChildrenOrder(parentNode)

    def NormalizeChildrenOrder(self, parentNode):
        if not parentNode.childList:
            return
        parentNode.childList.sort(key=lambda nodeValue: nodeValue.keyList[0])
        for childNode in parentNode.childList:
            childNode.parentNode = parentNode

# %% [markdown]
# Use the cell below to implement the requested API by means of **AVL Tree** (if among your chosen data structure).

# %%
class AVLTree(AbstractSearchInterface):

    def __init__(self):
        self.root = None
        self.inserted = False

    def insertElement(self, element):
        self.inserted = False
        self.root = AVLInsertHelper(self, self.root, element)
        return self.inserted

    def searchElement(self, element):
        return searchHelper(self.root, element)

# %% [markdown]
# Use the cell below to implement the requested API by means of **LLRB BST** (if among your chosen data structure).

# %%
class LLRBBST(AbstractSearchInterface):

    def __init__(self):
        self.root = None

    def insertElement(self, element):
        if _llrb_contains(self.root, element):
            return False
        self.root = _llrb_put(self.root, element, None)
        self.root.color = BLACK
        return True

    def searchElement(self, element):
        return _llrb_contains(self.root, element)

# %% [markdown]
# Use the cell below to implement the requested API by means of **B-Tree** (if among your chosen data structure).

# %%
class BTree(AbstractSearchInterface):
        
    def insertElement(self, element):
        inserted = False
        # ADD YOUR CODE HERE
      
        
        return inserted
    
    

    def searchElement(self, element):     
        found = False
        # ADD YOUR CODE HERE

        
        return found

# %% [markdown]
# Use the cell below to implement the requested API by means of **Scapegoat Tree** (if among your chosen data structure).

# %%
class ScapegoatTree(AbstractSearchInterface):
        
    def insertElement(self, element):
        inserted = False
        # ADD YOUR CODE HERE
      
        
        return inserted
    
    

    def searchElement(self, element):     
        found = False
        # ADD YOUR CODE HERE

        
        return found

# %% [markdown]
# Use the cell below to implement the **synthetic data generator** needed by your experimental framework (be mindful of code readability and reusability).

# %%
import string
import random

class TestDataGenerator():
    # the default alphabet is the ascii letters only
    def __init__(self, alphabet=string.ascii_letters, min_length=5, max_length=10):
        self.alphabet = alphabet
        self.length_range = (min_length, max_length)
        self.inserted = []
        self.inserted_set = set()
        self.search = []

    # generates strings of random length from range 5-10 as default
    def _generate_string(self):
        length = random.randint(self.length_range[0], self.length_range[1])
        return "".join(self.alphabet[random.randint(0, len(self.alphabet) - 1)] for _ in range(length))

    # generates the insertion dataset, varying in order
    def insert_dataset(self, n, order="random"):
        dataset = []
        seen = set()
        while len(dataset) < n:
            s = self._generate_string()
            if s not in seen:
                dataset.append(s)
                seen.add(s)
        match order:
            case "random":
                pass
            case "sorted":
                dataset.sort()
            case "reverse":
                dataset.sort(reverse=True)
            case "nearly_sorted":
                dataset.sort()
                for _ in range(len(dataset) // 4):
                    i = random.randint(0, len(dataset) - 1)
                    j = random.randint(0, len(dataset) - 1)
                    dataset[i], dataset[j] = dataset[j], dataset[i]
        self.inserted = dataset
        self.inserted_set = seen
        return dataset

    # generates a search dataset, of which the hit ratio can be defined
    def search_dataset(self, n, hit_ratio=0.5):
        hits = int(n * hit_ratio)
        misses = n - hits
        dataset = []
        seen = set()
        while len(dataset) < misses:
            s = self._generate_string()
            if s not in seen and s not in self.inserted_set:
                dataset.append(s)
                seen.add(s)
        dataset += random.sample(self.inserted, hits)
        random.shuffle(dataset)
        self.search = dataset
        return dataset

# %% [markdown]
# Use the cell below to implement the requested **experimental framework** (be mindful of code readability and reusability).

# %%
import timeit
import matplotlib.pyplot as plt

class ExperimentalFramework():

    def __init__(self, tree_class):
        self.tree_class = tree_class
        self.evaluation_results = []

    # insertion method
    def insertion(self, dataset):
        tree = self.tree_class()
        for s in dataset:
            tree.insertElement(s)
        return tree

    #search method
    def search(self, dataset, tree):
        for s in dataset:
            tree.searchElement(s)

    # evaluates the data structure based on the datasets
    def evaluation(self, insert_dataset, search_dataset, k):
        insert_time = timeit.timeit((lambda: self.insertion(insert_dataset)), number=k) / k
        tree = self.insertion(insert_dataset)
        search_time = timeit.timeit((lambda: self.search(search_dataset, tree)), number=k) / k
        return (insert_time, search_time)

    # comprehensively evaluates all structures according to varying parameters
    def evaluation_suite(self, sizes=None, hit_ratios=None, k=10, data_generator=None):
        if sizes is None:
            sizes = [1000, 5000, 10000, 50000, 100000]
        if hit_ratios is None:
            hit_ratios = [0.2, 0.5, 0.8]
        if data_generator is None:
            data_generator = TestDataGenerator()
        random.seed(47)
        orders = ["random", "sorted", "reverse", "nearly_sorted"]
        for n in sizes:
            for order in orders:
                insert_data = data_generator.insert_dataset(n, order)
                for hit_ratio in hit_ratios:
                    search_data = data_generator.search_dataset(n, hit_ratio)
                    insert_time, search_time = self.evaluation(insert_data, search_data, k)
                    self.evaluation_results.append({
                        'n': n,
                        'order': order,
                        'hit_ratio': hit_ratio,
                        'insert_time': insert_time,
                        'search_time': search_time,
                        'insert_per_element': insert_time / n,
                        'search_per_element': search_time / len(search_data)
                    })

# %% [markdown]
# Use the cell below to illustrate the python code you used to **fully evaluate** your three chosen search data structures and algortihms. The code below should illustrate, for example, how you made used of the **TestDataGenerator** class to generate test data of various size and properties; how you instatiated the **ExperimentalFramework** class to  evaluate each data structure using such data, collect information about their execution time, plot results, etc. Any results you illustrate in the companion PDF report should have been generated using the code below.

# %%
import platform, sys

print(f"OS:     {platform.system()} {platform.release()}")
print(f"CPU:    {platform.processor() or platform.machine()}")
print(f"Python: {sys.version}")
# Out:
# OS:     Darwin 24.2.0
# CPU:    arm
# Python: 3.13.7 (v3.13.7:bcee1c32211, Aug 14 2025, 19:10:51) [Clang 16.0.0 (clang-1600.0.26.6)]

# %%
# ADD YOUR TEST CODE HERE

def verify_edge_cases(tree_class, name):
    t = tree_class()
    assert t.searchElement("hello") == False

    t = tree_class()
    assert t.insertElement("hello") == True
    assert t.searchElement("hello") == True
    assert t.searchElement("world") == False

    t = tree_class()
    t.insertElement("hello")
    assert t.insertElement("hello") == False

    t = tree_class()
    for w in ["banana", "apple", "cherry", "date", "elderberry"]:
        t.insertElement(w)
    for w in ["banana", "apple", "cherry", "date", "elderberry"]:
        assert t.searchElement(w) == True
    assert t.searchElement("fig") == False

    print(f"{name}: edge cases passed")


verify_edge_cases(AVLTree, "AVLTree")
verify_edge_cases(TwoThreeTree, "TwoThreeTree")
verify_edge_cases(LLRBBST, "LLRBBST")

avl_experiment = ExperimentalFramework(AVLTree)
avl_experiment.evaluation_suite()

twothree_experiment = ExperimentalFramework(TwoThreeTree)
twothree_experiment.evaluation_suite()

llrb_experiment = ExperimentalFramework(LLRBBST)
llrb_experiment.evaluation_suite()

for result in avl_experiment.evaluation_results:
    print(f"AVL      | n={result['n']}, order={result['order']}, hit_ratio={result['hit_ratio']} -> insert={result['insert_time']:.4f}s, search={result['search_time']:.6f}s")
for result in twothree_experiment.evaluation_results:
    print(f"2-3 Tree | n={result['n']}, order={result['order']}, hit_ratio={result['hit_ratio']} -> insert={result['insert_time']:.4f}s, search={result['search_time']:.6f}s")
for result in llrb_experiment.evaluation_results:
    print(f"LLRB     | n={result['n']}, order={result['order']}, hit_ratio={result['hit_ratio']} -> insert={result['insert_time']:.4f}s, search={result['search_time']:.6f}s")

all_results = {
    'AVL': avl_experiment.evaluation_results,
    '2-3 Tree': twothree_experiment.evaluation_results,
    'LLRB': llrb_experiment.evaluation_results,
}

orders = ["random", "sorted", "reverse", "nearly_sorted"]
hit_ratios = [0.2, 0.5, 0.8]
sizes = [1000, 5000, 10000, 50000, 100000]

# varying the string lengths to compare short vs long strings for each structure
long_gen = TestDataGenerator(min_length=50, max_length=100)

avl_long = ExperimentalFramework(AVLTree)
avl_long.evaluation_suite(data_generator=long_gen)
twothree_long = ExperimentalFramework(TwoThreeTree)
twothree_long.evaluation_suite(data_generator=long_gen)
llrb_long = ExperimentalFramework(LLRBBST)
llrb_long.evaluation_suite(data_generator=long_gen)

string_results = {
    'AVL (5-10 chars)': avl_experiment.evaluation_results,
    'AVL (50-100 chars)': avl_long.evaluation_results,
    '2-3 Tree (5-10 chars)': twothree_experiment.evaluation_results,
    '2-3 Tree (50-100 chars)': twothree_long.evaluation_results,
    'LLRB (5-10 chars)': llrb_experiment.evaluation_results,
    'LLRB (50-100 chars)': llrb_long.evaluation_results,
}
# Out:
# AVLTree: edge cases passed
# TwoThreeTree: edge cases passed
# LLRBBST: edge cases passed
# AVL      | n=1000, order=random, hit_ratio=0.2 -> insert=0.0037s, search=0.000504s
# AVL      | n=1000, order=random, hit_ratio=0.5 -> insert=0.0019s, search=0.000276s
# AVL      | n=1000, order=random, hit_ratio=0.8 -> insert=0.0018s, search=0.000274s
# AVL      | n=1000, order=sorted, hit_ratio=0.2 -> insert=0.0019s, search=0.000297s
# AVL      | n=1000, order=sorted, hit_ratio=0.5 -> insert=0.0019s, search=0.000289s
# AVL      | n=1000, order=sorted, hit_ratio=0.8 -> insert=0.0019s, search=0.000267s
# AVL      | n=1000, order=reverse, hit_ratio=0.2 -> insert=0.0019s, search=0.000341s
# AVL      | n=1000, order=reverse, hit_ratio=0.5 -> insert=0.0018s, search=0.000279s
# AVL      | n=1000, order=reverse, hit_ratio=0.8 -> insert=0.0018s, search=0.000281s
# AVL      | n=1000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.0020s, search=0.000297s
# AVL      | n=1000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.0020s, search=0.000276s
# AVL      | n=1000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.0020s, search=0.000275s
# AVL      | n=5000, order=random, hit_ratio=0.2 -> insert=0.0113s, search=0.001926s
# AVL      | n=5000, order=random, hit_ratio=0.5 -> insert=0.0113s, search=0.001856s
# AVL      | n=5000, order=random, hit_ratio=0.8 -> insert=0.0115s, search=0.001792s
# AVL      | n=5000, order=sorted, hit_ratio=0.2 -> insert=0.0118s, search=0.001968s
# AVL      | n=5000, order=sorted, hit_ratio=0.5 -> insert=0.0118s, search=0.001862s
# AVL      | n=5000, order=sorted, hit_ratio=0.8 -> insert=0.0117s, search=0.001857s
# AVL      | n=5000, order=reverse, hit_ratio=0.2 -> insert=0.0114s, search=0.001989s
# AVL      | n=5000, order=reverse, hit_ratio=0.5 -> insert=0.0113s, search=0.001822s
# AVL      | n=5000, order=reverse, hit_ratio=0.8 -> insert=0.0113s, search=0.001804s
# AVL      | n=5000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.0125s, search=0.001964s
# AVL      | n=5000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.0126s, search=0.001914s
# AVL      | n=5000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.0126s, search=0.001836s
# AVL      | n=10000, order=random, hit_ratio=0.2 -> insert=0.0262s, search=0.004491s
# AVL      | n=10000, order=random, hit_ratio=0.5 -> insert=0.0288s, search=0.004471s
# AVL      | n=10000, order=random, hit_ratio=0.8 -> insert=0.0253s, search=0.004020s
# AVL      | n=10000, order=sorted, hit_ratio=0.2 -> insert=0.0263s, search=0.004331s
# AVL      | n=10000, order=sorted, hit_ratio=0.5 -> insert=0.0259s, search=0.004112s
# AVL      | n=10000, order=sorted, hit_ratio=0.8 -> insert=0.0274s, search=0.004007s
# AVL      | n=10000, order=reverse, hit_ratio=0.2 -> insert=0.0248s, search=0.004254s
# AVL      | n=10000, order=reverse, hit_ratio=0.5 -> insert=0.0250s, search=0.004128s
# AVL      | n=10000, order=reverse, hit_ratio=0.8 -> insert=0.0250s, search=0.004257s
# AVL      | n=10000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.0284s, search=0.004509s
# AVL      | n=10000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.0270s, search=0.004204s
# AVL      | n=10000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.0285s, search=0.004104s
# AVL      | n=50000, order=random, hit_ratio=0.2 -> insert=0.1596s, search=0.029714s
# AVL      | n=50000, order=random, hit_ratio=0.5 -> insert=0.1613s, search=0.026677s
# AVL      | n=50000, order=random, hit_ratio=0.8 -> insert=0.1590s, search=0.025919s
# AVL      | n=50000, order=sorted, hit_ratio=0.2 -> insert=0.1526s, search=0.027145s
# AVL      | n=50000, order=sorted, hit_ratio=0.5 -> insert=0.1521s, search=0.027836s
# AVL      | n=50000, order=sorted, hit_ratio=0.8 -> insert=0.1611s, search=0.029824s
# AVL      | n=50000, order=reverse, hit_ratio=0.2 -> insert=0.1509s, search=0.035784s
# AVL      | n=50000, order=reverse, hit_ratio=0.5 -> insert=0.1465s, search=0.030069s
# AVL      | n=50000, order=reverse, hit_ratio=0.8 -> insert=0.1465s, search=0.025485s
# AVL      | n=50000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.1697s, search=0.030131s
# AVL      | n=50000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.1649s, search=0.028495s
# AVL      | n=50000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.1877s, search=0.026289s
# AVL      | n=100000, order=random, hit_ratio=0.2 -> insert=0.3628s, search=0.074439s
# AVL      | n=100000, order=random, hit_ratio=0.5 -> insert=0.3381s, search=0.066408s
# AVL      | n=100000, order=random, hit_ratio=0.8 -> insert=0.3431s, search=0.059739s
# AVL      | n=100000, order=sorted, hit_ratio=0.2 -> insert=0.3266s, search=0.065909s
# AVL      | n=100000, order=sorted, hit_ratio=0.5 -> insert=0.3396s, search=0.065639s
# AVL      | n=100000, order=sorted, hit_ratio=0.8 -> insert=0.3264s, search=0.059433s
# AVL      | n=100000, order=reverse, hit_ratio=0.2 -> insert=0.3142s, search=0.101480s
# AVL      | n=100000, order=reverse, hit_ratio=0.5 -> insert=0.3156s, search=0.068320s
# AVL      | n=100000, order=reverse, hit_ratio=0.8 -> insert=0.3130s, search=0.059062s
# AVL      | n=100000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.3555s, search=0.071485s
# AVL      | n=100000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.3599s, search=0.072638s
# AVL      | n=100000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.3588s, search=0.062515s
# 2-3 Tree | n=1000, order=random, hit_ratio=0.2 -> insert=0.0020s, search=0.001579s
# 2-3 Tree | n=1000, order=random, hit_ratio=0.5 -> insert=0.0020s, search=0.001507s
# 2-3 Tree | n=1000, order=random, hit_ratio=0.8 -> insert=0.0020s, search=0.001435s
# 2-3 Tree | n=1000, order=sorted, hit_ratio=0.2 -> insert=0.0026s, search=0.001629s
# 2-3 Tree | n=1000, order=sorted, hit_ratio=0.5 -> insert=0.0026s, search=0.001574s
# 2-3 Tree | n=1000, order=sorted, hit_ratio=0.8 -> insert=0.0026s, search=0.001503s
# 2-3 Tree | n=1000, order=reverse, hit_ratio=0.2 -> insert=0.0021s, search=0.001602s
# 2-3 Tree | n=1000, order=reverse, hit_ratio=0.5 -> insert=0.0021s, search=0.001522s
# 2-3 Tree | n=1000, order=reverse, hit_ratio=0.8 -> insert=0.0021s, search=0.001457s
# 2-3 Tree | n=1000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.0022s, search=0.001627s
# 2-3 Tree | n=1000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.0022s, search=0.001553s
# 2-3 Tree | n=1000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.0022s, search=0.001495s
# 2-3 Tree | n=5000, order=random, hit_ratio=0.2 -> insert=0.0118s, search=0.010080s
# 2-3 Tree | n=5000, order=random, hit_ratio=0.5 -> insert=0.0119s, search=0.009670s
# 2-3 Tree | n=5000, order=random, hit_ratio=0.8 -> insert=0.0119s, search=0.009791s
# 2-3 Tree | n=5000, order=sorted, hit_ratio=0.2 -> insert=0.0157s, search=0.010988s
# 2-3 Tree | n=5000, order=sorted, hit_ratio=0.5 -> insert=0.0155s, search=0.010128s
# 2-3 Tree | n=5000, order=sorted, hit_ratio=0.8 -> insert=0.0153s, search=0.009801s
# 2-3 Tree | n=5000, order=reverse, hit_ratio=0.2 -> insert=0.0120s, search=0.010403s
# 2-3 Tree | n=5000, order=reverse, hit_ratio=0.5 -> insert=0.0120s, search=0.010064s
# 2-3 Tree | n=5000, order=reverse, hit_ratio=0.8 -> insert=0.0119s, search=0.009705s
# 2-3 Tree | n=5000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.0130s, search=0.010392s
# 2-3 Tree | n=5000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.0131s, search=0.009995s
# 2-3 Tree | n=5000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.0130s, search=0.009647s
# 2-3 Tree | n=10000, order=random, hit_ratio=0.2 -> insert=0.0254s, search=0.022066s
# 2-3 Tree | n=10000, order=random, hit_ratio=0.5 -> insert=0.0256s, search=0.021303s
# 2-3 Tree | n=10000, order=random, hit_ratio=0.8 -> insert=0.0255s, search=0.020792s
# 2-3 Tree | n=10000, order=sorted, hit_ratio=0.2 -> insert=0.0327s, search=0.023154s
# 2-3 Tree | n=10000, order=sorted, hit_ratio=0.5 -> insert=0.0327s, search=0.022332s
# 2-3 Tree | n=10000, order=sorted, hit_ratio=0.8 -> insert=0.0331s, search=0.023504s
# 2-3 Tree | n=10000, order=reverse, hit_ratio=0.2 -> insert=0.0254s, search=0.022934s
# 2-3 Tree | n=10000, order=reverse, hit_ratio=0.5 -> insert=0.0255s, search=0.023365s
# 2-3 Tree | n=10000, order=reverse, hit_ratio=0.8 -> insert=0.0255s, search=0.021601s
# 2-3 Tree | n=10000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.0281s, search=0.024032s
# 2-3 Tree | n=10000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.0281s, search=0.021933s
# 2-3 Tree | n=10000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.0284s, search=0.021677s
# 2-3 Tree | n=50000, order=random, hit_ratio=0.2 -> insert=0.1490s, search=0.141141s
# 2-3 Tree | n=50000, order=random, hit_ratio=0.5 -> insert=0.1487s, search=0.144429s
# 2-3 Tree | n=50000, order=random, hit_ratio=0.8 -> insert=0.1487s, search=0.141305s
# 2-3 Tree | n=50000, order=sorted, hit_ratio=0.2 -> insert=0.1889s, search=0.148623s
# 2-3 Tree | n=50000, order=sorted, hit_ratio=0.5 -> insert=0.1886s, search=0.149754s
# 2-3 Tree | n=50000, order=sorted, hit_ratio=0.8 -> insert=0.1913s, search=0.154541s
# 2-3 Tree | n=50000, order=reverse, hit_ratio=0.2 -> insert=0.1512s, search=0.156706s
# 2-3 Tree | n=50000, order=reverse, hit_ratio=0.5 -> insert=0.1422s, search=0.165532s
# 2-3 Tree | n=50000, order=reverse, hit_ratio=0.8 -> insert=0.1450s, search=0.143081s
# 2-3 Tree | n=50000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.1894s, search=0.149387s
# 2-3 Tree | n=50000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.1636s, search=0.144786s
# 2-3 Tree | n=50000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.1726s, search=0.138888s
# 2-3 Tree | n=100000, order=random, hit_ratio=0.2 -> insert=0.3319s, search=0.352083s
# 2-3 Tree | n=100000, order=random, hit_ratio=0.5 -> insert=0.3307s, search=0.320384s
# 2-3 Tree | n=100000, order=random, hit_ratio=0.8 -> insert=0.3333s, search=0.313609s
# 2-3 Tree | n=100000, order=sorted, hit_ratio=0.2 -> insert=0.4056s, search=0.371980s
# 2-3 Tree | n=100000, order=sorted, hit_ratio=0.5 -> insert=0.4019s, search=0.371864s
# 2-3 Tree | n=100000, order=sorted, hit_ratio=0.8 -> insert=0.4066s, search=0.341294s
# 2-3 Tree | n=100000, order=reverse, hit_ratio=0.2 -> insert=0.3035s, search=0.382232s
# 2-3 Tree | n=100000, order=reverse, hit_ratio=0.5 -> insert=0.3006s, search=0.353998s
# 2-3 Tree | n=100000, order=reverse, hit_ratio=0.8 -> insert=0.3022s, search=0.351503s
# 2-3 Tree | n=100000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.3877s, search=0.382535s
# 2-3 Tree | n=100000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.3821s, search=0.365519s
# 2-3 Tree | n=100000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.3722s, search=0.338365s
# LLRB     | n=1000, order=random, hit_ratio=0.2 -> insert=0.0018s, search=0.000313s
# LLRB     | n=1000, order=random, hit_ratio=0.5 -> insert=0.0018s, search=0.000298s
# LLRB     | n=1000, order=random, hit_ratio=0.8 -> insert=0.0019s, search=0.000285s
# LLRB     | n=1000, order=sorted, hit_ratio=0.2 -> insert=0.0018s, search=0.000316s
# LLRB     | n=1000, order=sorted, hit_ratio=0.5 -> insert=0.0018s, search=0.000299s
# LLRB     | n=1000, order=sorted, hit_ratio=0.8 -> insert=0.0019s, search=0.000306s
# LLRB     | n=1000, order=reverse, hit_ratio=0.2 -> insert=0.0022s, search=0.000313s
# LLRB     | n=1000, order=reverse, hit_ratio=0.5 -> insert=0.0021s, search=0.000303s
# LLRB     | n=1000, order=reverse, hit_ratio=0.8 -> insert=0.0021s, search=0.000285s
# LLRB     | n=1000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.0019s, search=0.000333s
# LLRB     | n=1000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.0019s, search=0.000311s
# LLRB     | n=1000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.0019s, search=0.000293s
# LLRB     | n=5000, order=random, hit_ratio=0.2 -> insert=0.0115s, search=0.002015s
# LLRB     | n=5000, order=random, hit_ratio=0.5 -> insert=0.0115s, search=0.001951s
# LLRB     | n=5000, order=random, hit_ratio=0.8 -> insert=0.0114s, search=0.001859s
# LLRB     | n=5000, order=sorted, hit_ratio=0.2 -> insert=0.0108s, search=0.002008s
# LLRB     | n=5000, order=sorted, hit_ratio=0.5 -> insert=0.0108s, search=0.001914s
# LLRB     | n=5000, order=sorted, hit_ratio=0.8 -> insert=0.0108s, search=0.001835s
# LLRB     | n=5000, order=reverse, hit_ratio=0.2 -> insert=0.0130s, search=0.002030s
# LLRB     | n=5000, order=reverse, hit_ratio=0.5 -> insert=0.0130s, search=0.001962s
# LLRB     | n=5000, order=reverse, hit_ratio=0.8 -> insert=0.0130s, search=0.001876s
# LLRB     | n=5000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.0115s, search=0.002065s
# LLRB     | n=5000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.0115s, search=0.001934s
# LLRB     | n=5000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.0116s, search=0.001854s
# LLRB     | n=10000, order=random, hit_ratio=0.2 -> insert=0.0246s, search=0.004498s
# LLRB     | n=10000, order=random, hit_ratio=0.5 -> insert=0.0245s, search=0.004360s
# LLRB     | n=10000, order=random, hit_ratio=0.8 -> insert=0.0247s, search=0.004156s
# LLRB     | n=10000, order=sorted, hit_ratio=0.2 -> insert=0.0234s, search=0.004553s
# LLRB     | n=10000, order=sorted, hit_ratio=0.5 -> insert=0.0236s, search=0.004280s
# LLRB     | n=10000, order=sorted, hit_ratio=0.8 -> insert=0.0234s, search=0.004148s
# LLRB     | n=10000, order=reverse, hit_ratio=0.2 -> insert=0.0282s, search=0.004498s
# LLRB     | n=10000, order=reverse, hit_ratio=0.5 -> insert=0.0282s, search=0.004228s
# LLRB     | n=10000, order=reverse, hit_ratio=0.8 -> insert=0.0282s, search=0.004152s
# LLRB     | n=10000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.0249s, search=0.004543s
# LLRB     | n=10000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.0248s, search=0.004310s
# LLRB     | n=10000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.0249s, search=0.004201s
# LLRB     | n=50000, order=random, hit_ratio=0.2 -> insert=0.1472s, search=0.027558s
# LLRB     | n=50000, order=random, hit_ratio=0.5 -> insert=0.1501s, search=0.026903s
# LLRB     | n=50000, order=random, hit_ratio=0.8 -> insert=0.1524s, search=0.028268s
# LLRB     | n=50000, order=sorted, hit_ratio=0.2 -> insert=0.1478s, search=0.029266s
# LLRB     | n=50000, order=sorted, hit_ratio=0.5 -> insert=0.1397s, search=0.028833s
# LLRB     | n=50000, order=sorted, hit_ratio=0.8 -> insert=0.1398s, search=0.025779s
# LLRB     | n=50000, order=reverse, hit_ratio=0.2 -> insert=0.1687s, search=0.028340s
# LLRB     | n=50000, order=reverse, hit_ratio=0.5 -> insert=0.1681s, search=0.026904s
# LLRB     | n=50000, order=reverse, hit_ratio=0.8 -> insert=0.1679s, search=0.026139s
# LLRB     | n=50000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.1522s, search=0.028483s
# LLRB     | n=50000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.1531s, search=0.029302s
# LLRB     | n=50000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.1499s, search=0.026303s
# LLRB     | n=100000, order=random, hit_ratio=0.2 -> insert=0.3231s, search=0.070173s
# LLRB     | n=100000, order=random, hit_ratio=0.5 -> insert=0.3337s, search=0.066304s
# LLRB     | n=100000, order=random, hit_ratio=0.8 -> insert=0.3319s, search=0.061829s
# LLRB     | n=100000, order=sorted, hit_ratio=0.2 -> insert=0.3000s, search=0.071365s
# LLRB     | n=100000, order=sorted, hit_ratio=0.5 -> insert=0.3005s, search=0.073326s
# LLRB     | n=100000, order=sorted, hit_ratio=0.8 -> insert=0.3039s, search=0.073996s
# LLRB     | n=100000, order=reverse, hit_ratio=0.2 -> insert=0.3649s, search=0.079130s
# LLRB     | n=100000, order=reverse, hit_ratio=0.5 -> insert=0.3640s, search=0.066604s
# LLRB     | n=100000, order=reverse, hit_ratio=0.8 -> insert=0.3683s, search=0.070490s
# LLRB     | n=100000, order=nearly_sorted, hit_ratio=0.2 -> insert=0.3358s, search=0.080012s
# LLRB     | n=100000, order=nearly_sorted, hit_ratio=0.5 -> insert=0.3397s, search=0.076934s
# LLRB     | n=100000, order=nearly_sorted, hit_ratio=0.8 -> insert=0.3332s, search=0.065404s

# %%
# insert time vs n, broken down by insertion order (hit_ratio fixed at 0.5)
for label, results in all_results.items():
    for order in orders:
        entries = [entry for entry in results if entry['order'] == order and entry['hit_ratio'] == 0.5]
        plt.plot([entry['n'] for entry in entries], [entry['insert_time'] for entry in entries], marker='o', label=f"{label} ({order})")
plt.xlabel('n')
plt.ylabel('insert time (s)')
plt.title('Insert time vs n by insertion order')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# search time vs n, random insertion order, varying hit ratio
for label, results in all_results.items():
    for hr in hit_ratios:
        entries = [entry for entry in results if entry['order'] == 'random' and entry['hit_ratio'] == hr]
        plt.plot([entry['n'] for entry in entries], [entry['search_time'] for entry in entries], marker='o', label=f"{label} (hit={hr})")
plt.xlabel('n')
plt.ylabel('search time (s)')
plt.title('Search time vs n (random order)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# normalised per-element insert cost
for label, results in all_results.items():
    for order in orders:
        entries = [entry for entry in results if entry['order'] == order and entry['hit_ratio'] == 0.5]
        plt.plot([entry['n'] for entry in entries], [entry['insert_per_element'] for entry in entries], marker='o', label=f"{label} ({order})")
plt.xlabel('n')
plt.ylabel('insert time per element (s)')
plt.title('Per-element insert cost vs n')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# normalised per-element search cost
for label, results in all_results.items():
    for hr in hit_ratios:
        entries = [entry for entry in results if entry['order'] == 'random' and entry['hit_ratio'] == hr]
        plt.plot([entry['n'] for entry in entries], [entry['search_per_element'] for entry in entries], marker='o', label=f"{label} (hit={hr})")
plt.xlabel('n')
plt.ylabel('search time per element (s)')
plt.title('Per-element search cost vs n')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# bar chart: insert time by order at n=100k
width = 0.25
for i, (label, results) in enumerate(all_results.items()):
    entries = [entry for entry in results if entry['n'] == 100000 and entry['hit_ratio'] == 0.5]
    times = [entry['insert_time'] for entry in entries]
    plt.bar([x + i * width for x in range(len(orders))], times, width, label=label, alpha=0.8)
plt.xticks([x + width for x in range(len(orders))], orders)
plt.xlabel('insertion order')
plt.ylabel('insert time (s)')
plt.title('Insert time by order at n=100k')
plt.legend()
plt.grid(True, axis='y', alpha=0.3)
plt.show()

# insert vs search cost per element at n=100k (random, hit=0.5)
tree_labels = list(all_results.keys())
insert_vals, search_vals = [], []
for label, results in all_results.items():
    entry = next(e for e in results if e['n'] == 100000 and e['order'] == 'random' and e['hit_ratio'] == 0.5)
    insert_vals.append(entry['insert_per_element'] * 1e6)
    search_vals.append(entry['search_per_element'] * 1e6)
x = range(len(tree_labels))
plt.bar([i - 0.175 for i in x], insert_vals, 0.35, label='insert', alpha=0.8)
plt.bar([i + 0.175 for i in x], search_vals, 0.35, label='search', alpha=0.8)
plt.xticks(x, tree_labels)
plt.ylabel('time per element (µs)')
plt.title('Insert vs search cost per element (n=100k, random)')
plt.legend()
plt.grid(True, axis='y', alpha=0.3)
plt.show()

# effect of string length on per-element search cost
for label, results in string_results.items():
    entries = [entry for entry in results if entry['order'] == 'random' and entry['hit_ratio'] == 0.5]
    plt.plot([entry['n'] for entry in entries], [entry['search_per_element'] for entry in entries], marker='o', label=label)
plt.xlabel('n')
plt.ylabel('search time per element (s)')
plt.title('Per-element search cost: short vs long strings')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
